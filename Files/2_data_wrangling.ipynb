# %% [markdown]
# ## I.2 Explore and perform Data Wrangling on:
#
# 1. Dataset: Scrapped Dataset of Properties listed in Birmingham B28 + 1 mile Radius (rightmove.co.uk)
# 2. Scrapped date: 4, Nov, 2024
# 3. Author: Lam H. Tong

# %%
# Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import geopy

# %%
# Import scrapped dataset

# All properties listed
df_all     = pd.read_csv('[all]B28_plus_1mile_rightmove_4_Nov.csv')

# Properties with garden only
df_garden = pd.read_csv('[garden]B28_plus_1mile_rightmove_4_Nov.csv')

# Properties with parking only
df_parking = pd.read_csv('[parking]B28_plus_1mile_rightmove_4_Nov.csv')

# New home only
df_new    = pd.read_csv('[new]B28_plus_1mile_rightmove_4_Nov.csv')

# %%
# The main dataframe info before wrangling
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 752 entries, 0 to 751
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   address  752 non-null    object
#  1   price    752 non-null    object
#  2   type     752 non-null    object
#  3   no_bed   752 non-null    object
#  4   no_bath  752 non-null    object
#  5   agent    752 non-null    object
#  6   url      752 non-null    object
# dtypes: object(7)
# memory usage: 41.3+ KB

# %%
# remove excessive characters
for df in [df_garden, df_new, df_parking, df_all]:
    df['price'] = df['price'].str.replace('£', '')

# drop duplicates (as every scrapped pages have 1 same advertised property):
df_all = df_all.drop_duplicates()
df_garden = df_garden.drop_duplicates()
df_new = df_new.drop_duplicates()
df_parking = df_parking.drop_duplicates()

# %%
# Adding featured coulumns in the filtered dataset 
df_parking['parking'] = True
df_garden['garden'] = True
df_new['new_home'] = True

# %%
#change 'no_bed' type to string to perform merging bc sh only this feild of this particular dataset is int64
df_garden['no_bed'] = df_garden['no_bed'].astype(str)

# merge the df_all with df_garden first
df_temp1 = pd.merge(df_all, df_garden, on = ['address', 'price', 'type', 'no_bed', 'no_bath', 'agent', 'url'] , how = 'outer')

# merge with df_parking
df_temp2 = pd.merge(df_temp1, df_parking, on = ['address', 'price', 'type', 'no_bed', 'no_bath', 'agent', 'url'] , how = 'outer')

#change 'no_bed' type to string to perform merging
df_new['no_bed'] = df_new['no_bed'].astype(str)

# the final merged dataframe
df = pd.merge(df_temp2, df_new, on = ['address', 'price', 'type', 'no_bed', 'no_bath', 'agent', 'url'] , how = 'outer')

# %%
# Define the regex pattern for UK postcodes
postcode_pattern = r'(\bB\d{1,2}(?:\s?\d[A-Z]{2})?\b)'

# Extract postcodes using .str.extract() and the pattern if there're any
df['postcode'] = df['address'].str.extract(postcode_pattern)

# Replace excessive newlines and carriage returns with a single space
df['address'] = df['address'].str.replace(r'[\n\r]+', ' ', regex=True)

# %%
# Replace 'not_specified' with NaN for `no_bed` and `no_bath`
df['no_bed'].replace('not_specified', np.nan, inplace=True)
df['no_bath'].replace('not_specified', np.nan, inplace=True)

# Remove commas and convert `price` to int
df['price'] = pd.to_numeric(df['price'].str.replace(',', ''), errors='coerce')

# Convert `no_bed` and `no_bath` to numeric, allowing NaNs
df['no_bed'] = pd.to_numeric(df['no_bed'], errors='coerce')
df['no_bath'] = pd.to_numeric(df['no_bath'], errors='coerce')

# Convert to nullable integer type (Int64) to handle NaNs
df['no_bed'] = df['no_bed'].astype('Int64')  # Nullable int
df['no_bath'] = df['no_bath'].astype('Int64')  # Nullable int

# Replacing Nulls in 'garden', 'parking', and 'new_home' as False
for feature in ['garden', 'parking', 'new_home']:
    df.loc[df[feature].isna(), feature] = False
# Out:
# C:\Users\blueb\AppData\Local\Temp\ipykernel_19744\2775976841.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['no_bed'].replace('not_specified', np.nan, inplace=True)
# C:\Users\blueb\AppData\Local\Temp\ipykernel_19744\2775976841.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['no_bath'].replace('not_specified', np.nan, inplace=True)

# %%
df[df['no_bath'].isna()]
# Out:
#                                                                                         address  \
# 0                                                            121 Brook Lane, Birmingham B13 0AB
# 71                                               Bradnock Close, Birmingham, West Midlands, B13
# 79                                                       Broadoaks, Streetsbrook Road, Solihull
# 82                                                               Bromwall Road, Birmingham, B13
# 219                           Garages to the rear of, 9-49 Ravenshill Road, Birmingham, B14 4HL
# 220                               Garden Bungalow, 31 Oxford Road, Moseley, Birmingham, B13 9EH
# 303                                                                James Court, Wake Green Park
# 433                                                  Princethorpe Close, Shirley, Solihull, B90
# 494                            Shaftmoor Lane, Hall Green, Birmingham,  West Midlands,  B28 8SW
# 495                            Shaftmoor Lane, Hall Green, Birmingham,  West Midlands,  B28 8SW
# 496                            Shaftmoor Lane, Hall Green, Birmingham,  West Midlands,  B28 8SW
# 497                            Shaftmoor Lane, Hall Green, Birmingham,  West Midlands,  B28 8SW
# 498                            Shaftmoor Lane, Hall Green, Birmingham,  West Midlands,  B28 8SW
# 499                            Shaftmoor Lane, Hall Green, Birmingham,  West Midlands,  B28 8SW
# 500                            Shaftmoor Lane, Hall Green, Birmingham,  West Midlands,  B28 8SW
# 501                                          Shaftmoor Lane, Hall Green, West Midlands, B28 8SN
# 502                                          Shaftmoor Lane, Hall Green, West Midlands, B28 8SN
# 503                                          Shaftmoor Lane, Hall Green, West Midlands, B28 8SN
# 504                                          Shaftmoor Lane, Hall Green, West Midlands, B28 8SN
# 505                                          Shaftmoor Lane, Hall Green, West Midlands, B28 8SN
# 506                                          Shaftmoor Lane, Hall Green, West Midlands, B28 8SN
# 507                                          Shaftmoor Lane, Hall Green, West Midlands, B28 8SN
# 508                                          Shaftmoor Lane, Hall Green, West Midlands, B28 8SN
# 509                                          Shaftmoor Lane, Hall Green, West Midlands, B28 8SN
# 510                                          Shaftmoor Lane, Hall Green, West Midlands, B28 8SN
# 548                                                  Springfield Road, Moseley, Birmingham, B13
# 628  Unit 130 Bridge House Hotel, Sherbourne Road, Acocks Green, Birmingham, West Midlands, B27
# 639                                                                 Wake Green Park, Birmingham
# 640                                                            Wake Green Park, Birmingham, B13
# 655                                                               Warwick Road, Birmingham, B11
#
#       price            type  no_bed  no_bath  \
# 0     99500        Terraced       2     <NA>
# 71   250000   Semi-Detached       3     <NA>
# 79   180000          Studio       1     <NA>
# 82   245000  End of Terrace       3     <NA>
# 219  225000   Land for sale    <NA>     <NA>
# 220  140000        Bungalow       2     <NA>
# 303  100000            Flat       1     <NA>
# 433  450000   Semi-Detached       6     <NA>
# 494  320000  End of Terrace       2     <NA>
# 495  399995   Semi-Detached       3     <NA>
# 496  399995   Semi-Detached       3     <NA>
# 497  445000        Detached       3     <NA>
# 498  445000        Detached       3     <NA>
# 499  520000        Detached       4     <NA>
# 500  525000        Detached       4     <NA>
# 501  330995        Terraced       3     <NA>
# 502  379995        Detached       3     <NA>
# 503  381995        Detached       3     <NA>
# 504  389995        Detached       3     <NA>
# 505  394995   Semi-Detached       4     <NA>
# 506  394995   Semi-Detached       4     <NA>
# 507  404995        Detached       3     <NA>
# 508  459995   Semi-Detached       5     <NA>
# 509  459995   Semi-Detached       5     <NA>
# 510  469995   Semi-Detached       5     <NA>
# 548  375000   Semi-Detached       4     <NA>
# 628    5000       Apartment    <NA>     <NA>
# 639   70000            Flat       1     <NA>
# 640  110000     Ground Flat       1     <NA>
# 655  260000        Terraced       1     <NA>
#
#                                     agent  \
# 0       SDL Property Auctions, Nationwide
# 71                    Dixons, Kings Heath
# 79                  Set To Let, Leicester
# 82      Express Estate Agency, Nationwide
# 219          Bond Wolfe, Commercial Sales
# 220                  Bond Wolfe, Auctions
# 303        Rice Chamberlains LLP, Moseley
# 433  Urban Edge Estates, Covering Shirley
# 494                    David Wilson Homes
# 495                    David Wilson Homes
# 496                    David Wilson Homes
# 497                    David Wilson Homes
# 498                    David Wilson Homes
# 499                    David Wilson Homes
# 500                    David Wilson Homes
# 501                         Barratt Homes
# 502                         Barratt Homes
# 503                         Barratt Homes
# 504                         Barratt Homes
# 505                         Barratt Homes
# 506                         Barratt Homes
# 507                         Barratt Homes
# 508                         Barratt Homes
# 509                         Barratt Homes
# 510                         Barratt Homes
# 548     Robert Oulsnam & Company, Moseley
# 628             Benjamin Stevens, Edgware
# 639                 Connells, Kings Heath
# 640     Purplebricks, covering Birmingham
# 655                         not_specified
#
#                                                                     url  \
# 0    https://www.rightmove.co.uk/properties/154574144#/?channel=RES_BUY
# 71   https://www.rightmove.co.uk/properties/154066088#/?channel=RES_BUY
# 79   https://www.rightmove.co.uk/properties/145873511#/?channel=RES_BUY
# 82   https://www.rightmove.co.uk/properties/151981685#/?channel=RES_BUY
# 219  https://www.rightmove.co.uk/properties/150797960#/?channel=COM_BUY
# 220  https://www.rightmove.co.uk/properties/153279509#/?channel=RES_BUY
# 303  https://www.rightmove.co.uk/properties/153012953#/?channel=RES_BUY
# 433   https://www.rightmove.co.uk/properties/86928021#/?channel=RES_BUY
# 494  https://www.rightmove.co.uk/properties/154177844#/?channel=RES_BUY
# 495  https://www.rightmove.co.uk/properties/149527079#/?channel=RES_BUY
# 496  https://www.rightmove.co.uk/properties/149644874#/?channel=RES_BUY
# 497  https://www.rightmove.co.uk/properties/148910312#/?channel=RES_BUY
# 498  https://www.rightmove.co.uk/properties/154084715#/?channel=RES_BUY
# 499  https://www.rightmove.co.uk/properties/153971048#/?channel=RES_BUY
# 500  https://www.rightmove.co.uk/properties/150969773#/?channel=RES_BUY
# 501  https://www.rightmove.co.uk/properties/151443134#/?channel=RES_BUY
# 502  https://www.rightmove.co.uk/properties/143029916#/?channel=RES_BUY
# 503  https://www.rightmove.co.uk/properties/147326681#/?channel=RES_BUY
# 504  https://www.rightmove.co.uk/properties/153918752#/?channel=RES_BUY
# 505  https://www.rightmove.co.uk/properties/153762278#/?channel=RES_BUY
# 506  https://www.rightmove.co.uk/properties/153762281#/?channel=RES_BUY
# 507  https://www.rightmove.co.uk/properties/153918755#/?channel=RES_BUY
# 508  https://www.rightmove.co.uk/properties/150458210#/?channel=RES_BUY
# 509  https://www.rightmove.co.uk/properties/150458213#/?channel=RES_BUY
# 510  https://www.rightmove.co.uk/properties/154136225#/?channel=RES_BUY
# 548  https://www.rightmove.co.uk/properties/150738041#/?channel=RES_BUY
# 628  https://www.rightmove.co.uk/properties/149856053#/?channel=RES_BUY
# 639  https://www.rightmove.co.uk/properties/150787394#/?channel=RES_BUY
# 640  https://www.rightmove.co.uk/properties/143628281#/?channel=RES_BUY
# 655  https://www.rightmove.co.uk/properties/151099451#/?channel=RES_BUY
#
#     garden parking new_home postcode
# 0    False    True    False  B13 0AB
# 71    True    True    False      B13
# 79   False    True    False      NaN
# 82    True    True    False      B13
# 219  False    True    False  B14 4HL
# 220   True    True    False  B13 9EH
# 303  False    True    False      NaN
# 433   True    True    False      B90
# 494   True    True     True  B28 8SW
# 495   True    True     True  B28 8SW
# 496   True    True     True  B28 8SW
# 497   True    True     True  B28 8SW
# 498   True    True     True  B28 8SW
# 499   True    True     True  B28 8SW
# 500   True    True     True  B28 8SW
# 501   True    True     True  B28 8SN
# 502   True   False     True  B28 8SN
# 503  False    True     True  B28 8SN
# 504   True    True     True  B28 8SN
# 505  False    True     True  B28 8SN
# 506   True    True     True  B28 8SN
# 507   True    True     True  B28 8SN
# 508   True    True     True  B28 8SN
# 509   True   False     True  B28 8SN
# 510   True    True     True  B28 8SN
# 548   True    True    False      B13
# 628  False   False    False      B27
# 639  False    True    False      NaN
# 640   True    True    False      B13
# 655  False    True    False      B11

# %%
# Correcting Bathrooms manunally as per the provided floor plan AND description of each property
for idx in [0, 79, 82, 220, 303, 639, 640, 655]:
    df.loc[idx, 'no_bath'] = 1

for idx in [71]:
    df.loc[idx, 'no_bath'] = 2

for idx in [433, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 548]:
    df.loc[idx, 'no_bath'] = 3

# %%
df[df['no_bed'].isna()]
# Out:
# Empty DataFrame
# Columns: [address, price, type, no_bed, no_bath, agent, url, garden, parking, new_home, postcode]
# Index: []

# %%
#Remove the above properties as they are commercial buildings
df = df.drop(index = [219, 628])

# %%
# Correcting types of these properties
df.loc[58, 'type'] = 'Flat'
df.loc[88, 'type'] = 'Semi-Detached'

# Drop the Commercial Property 
df = df.drop(686, axis = 0)

# %%
# Export to a separted dadaset
df.to_csv('B28_properties_dataset_cleaned.csv', index=False)
